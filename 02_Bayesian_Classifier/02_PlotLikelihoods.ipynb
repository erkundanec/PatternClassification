# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Function-to-compute-Gaussian-Distribution" data-toc-modified-id="Function-to-compute-Gaussian-Distribution-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Function to compute Gaussian Distribution</a></span></li></ul></div>

# %%
# %matplotlib inline
import os
from IPython.core.display import HTML
def load_style(directory = '../', name='customMac.css'):  
        styles = open(os.path.join(directory, name), 'r').read()
        return HTML(styles)
load_style()
# Out:
# <style>
# @import url('http://fonts.googleapis.com/css?family=Source+Code+Pro');
# @import url('http://fonts.googleapis.com/css?family=Lora');
#
# .CodeMirror pre, .CodeMirror-dialog, .CodeMirror-dialog .CodeMirror-search-field, .terminal-app .terminal {
#     font-family: YOUR-FAV-FONT;
#     font-size: 16pt;
# }
#
# .CodeMirror pre {
#     font-family: "Ubuntu", monospace;
# }
#     div.cell{
#         width: 950px;
#         #margin-left: 0% !important;
#         #margin-right: auto;
#     }
#     div.text_cell_render{
#         font-family: "Ubuntu";
#         line-height: 115%;
#         font-size: 140%;
#         text-align: justify;
#         text-justify:inter-word;
#     }
#     div.text_cell code {
#         background: transparent;
#         color: #000000;
#         font-weight: 400;
#         font-size: 12pt;
#         font-family:  'Source Code Pro', Consolas, monocco, monospace;
#    }
#     h1 {
#         font-family: "Ubuntu";
# 	}
#
#     div.input_area {
# ...

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import rc
import math
import matplotlib.pylab as pylab

params = {'legend.fontsize': 'x-large',
          'figure.figsize': (9,6),
         'axes.labelsize': 18,
         'axes.titlesize':18,
         'xtick.labelsize':18,
         'ytick.labelsize':18}
pylab.rcParams.update(params)
plt.rcParams.update({'font.size': 14})
rc('text', usetex=True)

# %% [markdown]
# ## Function to compute Gaussian Distribution

# %%
def pdf(x, mu, sigma):
    """
    Calculates the normal distribution's probability density 
    function (PDF).     
    """
    term1 = 1.0 / ( math.sqrt(2*np.pi) * sigma )
    term2 = np.exp( -0.5 * ( (x-mu)/sigma )**2 )
    return term1*term2

# %%
# generating some sample data
x = np.arange(-20, 40, 0.05)

# probability density functions
pdf1 = pdf(x, mu=4, sigma=6)
pdf2 = pdf(x, mu=14, sigma=4)

# %%
# Class conditional densities (likelihoods)
plt.plot(x, pdf1)
plt.plot(x, pdf2)
plt.ylabel('$p(x/\omega_i)$',fontsize=20)
plt.xlabel('random variable $x$',fontsize=20)
plt.legend([r'$\omega_1$', '$\omega_2$'], loc='upper left')
plt.annotate(r'male', xy=(1,0.06), xytext=(-4,0.08),
            arrowprops={'arrowstyle': '->'}, va='center',fontsize = 20)
plt.annotate(r'female', xy=(18,0.06), xytext=(30,0.08),
            arrowprops=dict(arrowstyle="->"), va='center',fontsize = 20)
plt.savefig('classProb.pdf') 
plt.show()
